# %% [markdown]
# <b>ΥΠΟΛΟΓΙΣΤΙΚΗ ΓΕΩΜΕΤΡΙΑ - ΕΡΓΑΣΙΑ ΣΕΠΤΕΜΒΡΙΟΥ</b> <br />
# ΟΝΟΜΑΤΕΠΩΝΥΜΟ: ΕΥΑΓΓΕΛΟΣ ΦΑΚΟΡΕΛΛΗΣ <br />
# ΑΡΙΘΜΟΣ ΜΗΤΡΩΟΥ: 1115201900203

# %% [markdown]
# <b>ΥΛΟΠΟΙΗΣΗ Α - ΚΥΡΤΟ ΠΕΡΙΒΛΗΜΑ</b>

# %% [markdown]
# <b>ΕΦΑΡΜΟΓΗ Α</b>

# %% [markdown]
# Παρακάτω φαίνονται σε λίστα και σχηματικά τα αποτελέσματα των αλγορίθμων και από κάτω φαίνεται ο συγκεντρωτικός πίνακας με τους χρόνους εκτέλεσης, ο οποίος δημιουργείται σε ζωντανό χρόνο μετά την εκτέλεση του προγράμματος.

# %%
import matplotlib.pyplot as plt
import time
from utils import *
from convex_hull.ConvexHull import ConvexHull, ConvexHullAlgorithms
from geometrical_search.GeometricalSearch import GeometricalSearch, GeometricalSearchAlgorithms
from geometrical_search.common.Rectangle import Rectangle

# %%
if __name__ == "__main__":
    for iteration in range(1,5):
        random_points = generate_random_points(num_points=100, min_value=0, max_value=1000)

        algorithms = [
            ConvexHullAlgorithms.INCREMENTAL_ALGORITHM,
            ConvexHullAlgorithms.GIFT_WRAPPING,
            ConvexHullAlgorithms.DIVIDE_AND_CONQUER,
            ConvexHullAlgorithms.QUICKHULL
        ]

        convex_hull_object = ConvexHull()
        times_object = {}

        for algorithm in algorithms:
            start_time = time.time()

            convex_hull_object.set_algorithm(algorithm)
            convex_hull_result = convex_hull_object.compute(random_points, False)

            convex_hull_object_list_result = convex_hull_result.print_as_list()
            convex_hull_object_diagram_result = convex_hull_result.plot_diagram()

            end_time = time.time()
            elapsed_time = end_time - start_time

            # Store the elapsed_time in the times_object dictionary
            times_object[str(algorithm)] = elapsed_time

        # Use the helper function to print the table
        print_algorithm_time_table(times_object)
# Out:
# [(16.0, 993.0), (730.0, 994.0), (845.0, 969.0), (983.0, 841.0), (995.0, 208.0), (879.0, 117.0), (614.0, 30.0), (146.0, 25.0), (119.0, 49.0), (54.0, 161.0), (34.0, 508.0)]
# [(16.0, 993.0), (730.0, 994.0), (845.0, 969.0), (983.0, 841.0), (995.0, 208.0), (879.0, 117.0), (614.0, 30.0), (146.0, 25.0), (119.0, 49.0), (54.0, 161.0), (34.0, 508.0)]
# [[34.0, 508.0], [878.0, 561.0], [65.0, 621.0]]
# [[146.0, 25.0], [614.0, 30.0], [879.0, 117.0], [995.0, 208.0], [983.0, 841.0], [845.0, 969.0], [730.0, 994.0], [16.0, 993.0], [34.0, 508.0], [54.0, 161.0], [119.0, 49.0]]
# +-------------------------------------------------+----------------------+
# | Algorithm                                       | Time Taken (seconds) |
# +-------------------------------------------------+----------------------+
# | ConvexHullAlgorithms.INCREMENTAL_ALGORITHM      | 0.13                 |
# +-------------------------------------------------+----------------------+
# ...

# %% [markdown]
# <b>Σχολιασμός Αποτελεσμάτων Αλγορίθμων</b>
#
# Αρχικά, παρουσιάζονται συνοπτικά οι πολυπλοκότητες χρόνου των παραπάνω αλγορίθμων: <br />
# Αυξητικός Αλγόριθμος Graham Scan: O(n*logn) <br />
# Αλγόριθμος Περιτυλίγματος: O(n^2) <br />
# Αλγόριθμος Διαίρε και Βασίλευε: O(n*logn) <br />
# Αλγόριθμος Quickhull: O(n*logh) <br />
#
# <b>Αυξητικός Αλγόριθμος Graham Scan:</b> <br />
# Ο αλγόριθμος αυτός παρουσιάζει σταθερό χρόνο εκτέλεσης σε όλες τις τρεις δοκιμές, με ελαφρύ περιθώριο διακύμανσης. <br />
#
# <b>Αλγόριθμος Περιτυλίγματος:</b> <br />
# Η απόδοση του Gift Wrapping είναι επίσης σταθερή, με μικρές αλλαγές στον χρόνο εκτέλεσης ανάμεσα στις διαφορετικές δοκιμές.<br />
#
# <b>Αλγόριθμος Διαίρε και Βασίλευε:</b><br />
# Είναι ενδιαφέρον να βλέπουμε ότι οι αλλαγές στα δεδομένα εισόδου μπορούν να επηρεάσουν την απόδοση του αλγορίθμου.
#
# <b>Αλγόριθμος Quickhull:</b><br />
# Η απόδοσή του είναι αντίστοιχη με τους άλλους αλγορίθμους. Φαίνεται, με μικρή διαφορά να είναι λίγο πιο αποδοτικός. <br />
#
# <b>Συμπεράσματα:</b>
# Ενώ η θεωρητική χρονική πολυπλοκότητα μπορεί να προσφέρει μια γενική ιδέα για την απόδοση των αλγορίθμων, οι πρακτικές εφαρμογές και δοκιμές μπορούν να διαφέρουν ανάλογα με τα δεδομένα εισόδου και την υλοποίηση. Στην περίπτωσή μας, όλοι οι αλγόριθμοι εμφανίζονται να έχουν παρόμοιες αποδόσεις για τα συγκεκριμένα δεδομένα, με τον QuickHull να φαίνεται λίγο πιο γρήγορος.

# %% [markdown]
# <b>Εκτέλεση Αλγορίθμου Quick Hull στον Τρισδιάστατο χώρο</b> <br />

# %%
points = generate_random_3d_points(80)
convex_hull_object.set_algorithm(ConvexHullAlgorithms.QUICKHULL)
convex_hull_result = convex_hull_object.compute(points, False)
# Out:
# [array([[0.96306199, 0.87766427, 0.79249698],
#        [0.84639992, 0.83164259, 0.08030384],
#        [0.87114081, 0.99829099, 0.79137273]]), array([[0.72645095, 0.12108439, 0.11445306],
#        [0.6195346 , 0.03398066, 0.27823546],
#        [0.00361064, 0.33414216, 0.00973525]]), array([[0.05748538, 0.88813789, 0.02460468],
#        [0.03608129, 0.79969951, 0.33533658],
#        [0.25297114, 0.97005234, 0.90349506]]), array([[0.05748538, 0.88813789, 0.02460468],
#        [0.03608129, 0.79969951, 0.33533658],
#        [0.00361064, 0.33414216, 0.00973525]]), array([[0.98786907, 0.67781726, 0.6524072 ],
#        [0.84639992, 0.83164259, 0.08030384],
#        [0.99864333, 0.22684894, 0.56562643]]), array([[0.98786907, 0.67781726, 0.6524072 ],
#        [0.96306199, 0.87766427, 0.79249698],
#        [0.84639992, 0.83164259, 0.08030384]]), array([[0.98786907, 0.67781726, 0.6524072 ],
#        [0.94712697, 0.23183256, 0.94884431],
# ...

# %% [markdown]
# Στο παρακάτω κελί θα εκτελέσουμε ξανά τον αυξητικό αλγόριθμο και θα οπτικοποιηθούν τα βήματα σε μορφή διαγραμμάτων. Στην συγκεκριμένη εκτέλεση του αλγορίθμου εισάγουμε 10 σημεία, καθώς ο αριθμός των βημάτων θα είναι ήδη αυξημένος.

# %%
random_points = generate_random_points(num_points=10, min_value=0, max_value=1000)

convex_hull_object = ConvexHull()
convex_hull_object.set_algorithm(ConvexHullAlgorithms.INCREMENTAL_ALGORITHM)
convex_hull_result = convex_hull_object.compute(random_points, True)

# %% [markdown]
# <b>ΥΛΟΠΟΙΗΣΗ Β - ΓΕΩΜΕΤΡΙΚΗ ΑΝΑΖΗΤΗΣΗ</b>

# %% [markdown]
# <b>ΕΦΑΡΜΟΓΗ Β</b>

# %% [markdown]
# Ο αλγόριθμος ορθογώνιας γεωμετρικής αναζήτησης που έχει υλοποιηθεί είναι εύρεση ορθογώνιας περιοχής μέσω KD-Trees

# %%
# Geometrical Search
random_70_points = generate_random_points(num_points=70, min_value=0, max_value=100)
random_2_points_rectangle = generate_random_points(num_points=2,min_value=1,max_value=99)

print(f"random 70 points: {random_70_points}")
print(f"random 2 points Rectangle: {random_2_points_rectangle}")

search_region = Rectangle(random_2_points_rectangle[0], random_2_points_rectangle[1])

geometrical_search_object = GeometricalSearch()
geometrical_search_object.set_algorithm(GeometricalSearchAlgorithms.KD_TREE_2D)
results = geometrical_search_object.compute(random_70_points, search_region)

print(f"Points in the region {search_region.bottom_left} to {search_region.top_right}: {results}")
# Out:
# random 70 points: [(46.0, 3.0), (93.0, 69.0), (53.0, 63.0), (9.0, 82.0), (81.0, 0.0), (98.0, 37.0), (11.0, 48.0), (8.0, 12.0), (14.0, 17.0), (6.0, 30.0), (93.0, 32.0), (87.0, 17.0), (97.0, 51.0), (49.0, 58.0), (41.0, 42.0), (24.0, 6.0), (63.0, 92.0), (45.0, 77.0), (83.0, 82.0), (47.0, 46.0), (70.0, 95.0), (12.0, 60.0), (35.0, 41.0), (83.0, 80.0), (24.0, 29.0), (35.0, 27.0), (81.0, 10.0), (95.0, 28.0), (86.0, 47.0), (59.0, 78.0), (10.0, 13.0), (66.0, 17.0), (30.0, 77.0), (34.0, 79.0), (97.0, 77.0), (17.0, 39.0), (72.0, 11.0), (61.0, 44.0), (49.0, 81.0), (36.0, 86.0), (8.0, 62.0), (18.0, 11.0), (85.0, 26.0), (67.0, 74.0), (15.0, 57.0), (60.0, 73.0), (82.0, 22.0), (48.0, 82.0), (36.0, 96.0), (95.0, 57.0), (20.0, 43.0), (64.0, 41.0), (26.0, 71.0), (75.0, 44.0), (87.0, 89.0), (10.0, 70.0), (65.0, 1.0), (84.0, 64.0), (95.0, 25.0), (2.0, 41.0), (44.0, 48.0), (42.0, 90.0), (41.0, 20.0), (17.0, 19.0), (6.0, 88.0), (76.0, 3.0), (64.0, 66.0), (7.0, 21.0), (30.0, 12.0), (49.0, 22.0)]
# ...

# %% [markdown]
# <b>Εφαρμογή Γ</b>

# %% [markdown]
# Κατόπιν κατάλληλης αναζήτησης, βρήκα την εξής πρακτική εφαρμογή του αλγορίθμου τριγωνοποίησης Delaunay:
#
# Παραγωγή ψηφιακών μοντέλων εδάφους (Digital Terrain Models - DTM) στην γεωπληροφορική.
#
# Ένα βήμα-βήμα παράδειγμα:
#
# Συλλογή δεδομένων: Έστω ότι έχουμε μια σειρά από σημεία με γεωγραφικές συντεταγμένες (longitude, latitude) και υψόμετρο. Αυτά τα σημεία μπορεί να προέρχονται από δορυφορικές λήψεις ή από εδαφικές μετρήσεις.
#
# Εφαρμογή της τριγωνοποιήσης: Εφαρμόζουμε τον αλγόριθμο τριγωνοποίησης Delaunay στα σημεία για να δημιουργήσουμε ένα δίκτυο τριγώνων που καλύπτει την περιοχή.
#
# Αποτύπωση: Με βάση τα τρίγωνα που προκύπτουν και τις τιμές υψομέτρου στις κορυφές τους, δημιουργούμε ένα 3D μοντέλο του εδάφους.
#
# Ανάλυση και οπτικοποίηση: Μπορούμε τώρα να χρησιμοποιήσουμε το ψηφιακό μας μοντέλο εδάφους για διάφορους σκοπούς, όπως την ανάλυση ροής υδάτων, την προβολή σκιών, τη δημιουργία περιβαλλοντικών μοντέλων και άλλα.
#
# Η τριγωνοποίηση Delaunay χρησιμοποιείται επίσης σε πολλές άλλες εφαρμογές, όπως στην αναγνώριση προτύπων, στην παραγωγή κωδικοποιημένων δικτύων για παιχνίδια και πολλά άλλα.
#
# Πηγή: http://geoinformatics.ntua.gr/courses/admcarto/lecture_notes/dtm%27s/dtm%27s.pdf
